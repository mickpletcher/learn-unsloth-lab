# %% [markdown]
# # Evaluation
# GPU cells are marked before use.

# %%
from learn_unsloth_lab.evaluation import run_evaluation
run_evaluation('../datasets/finance-lab/eval-prompts.jsonl', '../experiments/notebook-eval')
