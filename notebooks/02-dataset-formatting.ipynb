# %% [markdown]
# # Dataset Formatting
# GPU cells are marked before use.

# %%
from learn_unsloth_lab.dataset_validation import validate_dataset
validate_dataset('../datasets/finance-instructions.jsonl')
